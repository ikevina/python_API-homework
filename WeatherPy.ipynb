# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
# import openweathermapy as owm 
import urllib
from pprint import pprint


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
lat_lngs = []
cities = []

#Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats,lngs)

#Indentify nearest city for each lat,lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0],lat_lng[1]).city_name
    
    #If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

#Print the city count to confirm sufficient count
print(len(cities))
cities_df=pd.DataFrame(cities)
cities_df.head()
# Out:
# 601
#            0
# 0       tezu
# 1    rikitea
# 2    ushuaia
# 3  jamestown
# 4    may pen

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# testing if citypy is working
city1 = citipy.nearest_city(30.99, 122.21)
city1.city_name
# Out:
# 'shanghai'

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []
print("-----------------------------")
print("Beginning Data Retrieval     ")
print("-----------------------------")




# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:

        #retrieve data
        city_weather = requests.get(city_url).json()

        # max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 

print("----------------------------")
print("Data Retrieval Complete     ")
print("----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tezu
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | may pen
# Processing Record 6 of Set 1 | tefe
# Processing Record 7 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | skjervoy
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | deputatskiy
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | ronda
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | nanortalik
# Processing Record 21 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 22 of Set 1 | chapais
# Processing Record 23 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | rongcheng
# Processing Record 26 of Set 1 | ransang
# City not found. Skipping...
# Processing Record 27 of Set 1 | yulara
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | portree
# Processing Record 30 of Set 1 | nouadhibou
# Processing Record 31 of Set 1 | moville
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | ostrovnoy
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | vila franca do campo
# Processing Record 37 of Set 1 | salalah
# Processing Record 38 of Set 1 | kabanjahe
# Processing Record 39 of Set 1 | iquique
# Processing Record 40 of Set 1 | davila
# Processing Record 41 of Set 1 | ferme-neuve
# Processing Record 42 of Set 1 | havre-saint-pierre
# Processing Record 43 of Set 1 | mali
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | komsomolskiy
# Processing Record 46 of Set 1 | pundaguitan
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | ahuimanu
# Processing Record 49 of Set 1 | pokhara
# Processing Record 50 of Set 1 | bethel
# Processing Record 0 of Set 2 | ganzhou
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | antsohihy
# Processing Record 3 of Set 2 | talnakh
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | acarau
# City not found. Skipping...
# Processing Record 8 of Set 2 | viedma
# Processing Record 9 of Set 2 | mouila
# Processing Record 10 of Set 2 | meadow lake
# Processing Record 11 of Set 2 | kaitangata
# Processing Record 12 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 2 | yashan
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | warrington
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | jacqueville
# Processing Record 20 of Set 2 | obra
# Processing Record 21 of Set 2 | burica
# City not found. Skipping...
# Processing Record 22 of Set 2 | arlit
# Processing Record 23 of Set 2 | hay river
# Processing Record 24 of Set 2 | nelson bay
# Processing Record 25 of Set 2 | leshukonskoye
# Processing Record 26 of Set 2 | torbay
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 2 | griffin
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | traverse city
# Processing Record 32 of Set 2 | vilyuysk
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | kudahuvadhoo
# Processing Record 35 of Set 2 | constitucion
# Processing Record 36 of Set 2 | kruisfontein
# Processing Record 37 of Set 2 | grand gaube
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | kalisz
# Processing Record 40 of Set 2 | honningsvag
# Processing Record 41 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 2 | clyde river
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 2 | male
# Processing Record 46 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 2 | doha
# Processing Record 48 of Set 2 | longyearbyen
# Processing Record 49 of Set 2 | faratsiho
# Processing Record 0 of Set 3 | airai
# Processing Record 1 of Set 3 | alofi
# Processing Record 2 of Set 3 | souillac
# Processing Record 3 of Set 3 | mar del plata
# Processing Record 4 of Set 3 | toungoo
# City not found. Skipping...
# Processing Record 5 of Set 3 | tommot
# Processing Record 6 of Set 3 | richards bay
# Processing Record 7 of Set 3 | tuktoyaktuk
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | ponta do sol
# Processing Record 10 of Set 3 | husavik
# Processing Record 11 of Set 3 | saint-philippe
# Processing Record 12 of Set 3 | creel
# Processing Record 13 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 3 | fairbanks
# Processing Record 16 of Set 3 | aguie
# Processing Record 17 of Set 3 | namatanai
# Processing Record 18 of Set 3 | khatanga
# Processing Record 19 of Set 3 | new norfolk
# Processing Record 20 of Set 3 | progreso
# Processing Record 21 of Set 3 | hot springs
# Processing Record 22 of Set 3 | tomelloso
# Processing Record 23 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 3 | teya
# Processing Record 25 of Set 3 | chumikan
# Processing Record 26 of Set 3 | tulsa
# Processing Record 27 of Set 3 | maceio
# Processing Record 28 of Set 3 | pauini
# Processing Record 29 of Set 3 | gillette
# Processing Record 30 of Set 3 | saint george
# Processing Record 31 of Set 3 | coahuayana
# Processing Record 32 of Set 3 | lavrentiya
# Processing Record 33 of Set 3 | longkou
# Processing Record 34 of Set 3 | waipawa
# Processing Record 35 of Set 3 | caravelas
# Processing Record 36 of Set 3 | codrington
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | powell river
# Processing Record 39 of Set 3 | bubaque
# Processing Record 40 of Set 3 | carballo
# Processing Record 41 of Set 3 | sitka
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | zavodoukovsk
# Processing Record 44 of Set 3 | yumen
# Processing Record 45 of Set 3 | enshi
# Processing Record 46 of Set 3 | serebryansk
# Processing Record 47 of Set 3 | dikson
# Processing Record 48 of Set 3 | agadez
# Processing Record 49 of Set 3 | aripuana
# Processing Record 0 of Set 4 | santa marta
# Processing Record 1 of Set 4 | chiang klang
# Processing Record 2 of Set 4 | ust-maya
# Processing Record 3 of Set 4 | pingzhuang
# City not found. Skipping...
# Processing Record 4 of Set 4 | najran
# Processing Record 5 of Set 4 | denia
# Processing Record 6 of Set 4 | magadan
# Processing Record 7 of Set 4 | carnarvon
# Processing Record 8 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 9 of Set 4 | port elizabeth
# Processing Record 10 of Set 4 | sawasawa
# City not found. Skipping...
# Processing Record 11 of Set 4 | tiarei
# Processing Record 12 of Set 4 | hamilton
# Processing Record 13 of Set 4 | chuy
# Processing Record 14 of Set 4 | lakes entrance
# Processing Record 15 of Set 4 | roald
# Processing Record 16 of Set 4 | tuatapere
# Processing Record 17 of Set 4 | grafton
# Processing Record 18 of Set 4 | vestmannaeyjar
# Processing Record 19 of Set 4 | ancud
# Processing Record 20 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 4 | cap malheureux
# Processing Record 22 of Set 4 | viransehir
# Processing Record 23 of Set 4 | thompson
# Processing Record 24 of Set 4 | issenye
# Processing Record 25 of Set 4 | inhambane
# Processing Record 26 of Set 4 | norman wells
# Processing Record 27 of Set 4 | south lake tahoe
# Processing Record 28 of Set 4 | grand-santi
# Processing Record 29 of Set 4 | saint-augustin
# Processing Record 30 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 31 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 4 | namibe
# Processing Record 33 of Set 4 | trapani
# Processing Record 34 of Set 4 | stornoway
# City not found. Skipping...
# Processing Record 35 of Set 4 | lebyazhye
# Processing Record 36 of Set 4 | santa cruz
# Processing Record 37 of Set 4 | murray
# Processing Record 38 of Set 4 | longyan
# Processing Record 39 of Set 4 | galle
# Processing Record 40 of Set 4 | pervomayskiy
# Processing Record 41 of Set 4 | pisco
# Processing Record 42 of Set 4 | geraldton
# Processing Record 43 of Set 4 | vaitape
# Processing Record 44 of Set 4 | pangnirtung
# Processing Record 45 of Set 4 | yellowknife
# Processing Record 46 of Set 4 | high level
# Processing Record 47 of Set 4 | hirado
# Processing Record 48 of Set 4 | cabo san lucas
# Processing Record 49 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 0 of Set 5 | kisangani
# Processing Record 1 of Set 5 | vardo
# Processing Record 2 of Set 5 | mahebourg
# Processing Record 3 of Set 5 | abu dhabi
# Processing Record 4 of Set 5 | rio gallegos
# Processing Record 5 of Set 5 | laguna
# Processing Record 6 of Set 5 | bako
# Processing Record 7 of Set 5 | rolla
# Processing Record 8 of Set 5 | guerrero negro
# Processing Record 9 of Set 5 | lujiang
# Processing Record 10 of Set 5 | oranjemund
# Processing Record 11 of Set 5 | oistins
# Processing Record 12 of Set 5 | qaanaaq
# Processing Record 13 of Set 5 | yerbogachen
# Processing Record 14 of Set 5 | huarmey
# Processing Record 15 of Set 5 | amuntai
# Processing Record 16 of Set 5 | bambous virieux
# Processing Record 17 of Set 5 | shache
# Processing Record 18 of Set 5 | ornskoldsvik
# Processing Record 19 of Set 5 | qasigiannguit
# Processing Record 20 of Set 5 | ifanadiana
# Processing Record 21 of Set 5 | winchester
# Processing Record 22 of Set 5 | boa vista
# Processing Record 23 of Set 5 | lahaina
# Processing Record 24 of Set 5 | darhan
# Processing Record 25 of Set 5 | kununurra
# Processing Record 26 of Set 5 | ouallam
# Processing Record 27 of Set 5 | kavaratti
# Processing Record 28 of Set 5 | maldonado
# Processing Record 29 of Set 5 | hede
# Processing Record 30 of Set 5 | aginskoye
# Processing Record 31 of Set 5 | cooma
# Processing Record 32 of Set 5 | sharanga
# Processing Record 33 of Set 5 | chokurdakh
# Processing Record 34 of Set 5 | spentrup
# Processing Record 35 of Set 5 | gallup
# Processing Record 36 of Set 5 | kavieng
# Processing Record 37 of Set 5 | tessalit
# Processing Record 38 of Set 5 | bumba
# Processing Record 39 of Set 5 | aksarka
# Processing Record 40 of Set 5 | glenwood springs
# Processing Record 41 of Set 5 | mount isa
# Processing Record 42 of Set 5 | cuorgne
# Processing Record 43 of Set 5 | mnogovershinnyy
# Processing Record 44 of Set 5 | gamba
# Processing Record 45 of Set 5 | sobolevo
# Processing Record 46 of Set 5 | provideniya
# Processing Record 47 of Set 5 | melfort
# Processing Record 48 of Set 5 | matagami
# Processing Record 49 of Set 5 | hastings
# Processing Record 0 of Set 6 | taoudenni
# Processing Record 1 of Set 6 | adelaide
# Processing Record 2 of Set 6 | hinton
# Processing Record 3 of Set 6 | businga
# Processing Record 4 of Set 6 | shelburne
# Processing Record 5 of Set 6 | coolum beach
# Processing Record 6 of Set 6 | santiago
# Processing Record 7 of Set 6 | bella union
# Processing Record 8 of Set 6 | comodoro rivadavia
# Processing Record 9 of Set 6 | lata
# Processing Record 10 of Set 6 | coihaique
# Processing Record 11 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 6 | cherskiy
# Processing Record 13 of Set 6 | montepuez
# Processing Record 14 of Set 6 | katsuura
# Processing Record 15 of Set 6 | solnechnyy
# Processing Record 16 of Set 6 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 17 of Set 6 | kadnikov
# Processing Record 18 of Set 6 | nome
# Processing Record 19 of Set 6 | coruripe
# Processing Record 20 of Set 6 | waingapu
# Processing Record 21 of Set 6 | tuy hoa
# Processing Record 22 of Set 6 | port hardy
# Processing Record 23 of Set 6 | nhulunbuy
# Processing Record 24 of Set 6 | copala
# Processing Record 25 of Set 6 | leningradskiy
# Processing Record 26 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 6 | tilichiki
# Processing Record 28 of Set 6 | jangaon
# Processing Record 29 of Set 6 | belaya gora
# Processing Record 30 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 31 of Set 6 | macusani
# Processing Record 32 of Set 6 | yako
# Processing Record 33 of Set 6 | taltal
# Processing Record 34 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 35 of Set 6 | avarua
# Processing Record 36 of Set 6 | mecca
# Processing Record 37 of Set 6 | srednekolymsk
# Processing Record 38 of Set 6 | sao filipe
# Processing Record 39 of Set 6 | linxia
# Processing Record 40 of Set 6 | port blair
# Processing Record 41 of Set 6 | alyangula
# Processing Record 42 of Set 6 | popondetta
# Processing Record 43 of Set 6 | luebo
# Processing Record 44 of Set 6 | benjamin constant
# Processing Record 45 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 6 | naze
# Processing Record 47 of Set 6 | dickinson
# Processing Record 48 of Set 6 | havelock
# Processing Record 49 of Set 6 | terra santa
# Processing Record 0 of Set 7 | fuxin
# Processing Record 1 of Set 7 | polyarnyye zori
# Processing Record 2 of Set 7 | cockburn town
# Processing Record 3 of Set 7 | morehead
# Processing Record 4 of Set 7 | lagoa
# Processing Record 5 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 7 | bonthe
# Processing Record 7 of Set 7 | mogadishu
# Processing Record 8 of Set 7 | gedo
# Processing Record 9 of Set 7 | port hedland
# Processing Record 10 of Set 7 | yablochnyy
# Processing Record 11 of Set 7 | strezhevoy
# Processing Record 12 of Set 7 | russell
# Processing Record 13 of Set 7 | maxixe
# Processing Record 14 of Set 7 | kodiak
# Processing Record 15 of Set 7 | los llanos de aridane
# Processing Record 16 of Set 7 | tasiilaq
# Processing Record 17 of Set 7 | mandalgovi
# Processing Record 18 of Set 7 | fougamou
# Processing Record 19 of Set 7 | te anau
# Processing Record 20 of Set 7 | umm lajj
# Processing Record 21 of Set 7 | miandrivazo
# Processing Record 22 of Set 7 | kaoma
# Processing Record 23 of Set 7 | hasaki
# Processing Record 24 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 25 of Set 7 | sakyla
# Processing Record 26 of Set 7 | nemuro
# Processing Record 27 of Set 7 | jumla
# Processing Record 28 of Set 7 | makrana
# Processing Record 29 of Set 7 | mardin
# Processing Record 30 of Set 7 | kaduy
# Processing Record 31 of Set 7 | broken hill
# Processing Record 32 of Set 7 | porto velho
# Processing Record 33 of Set 7 | kattivakkam
# Processing Record 34 of Set 7 | turayf
# Processing Record 35 of Set 7 | zabol
# Processing Record 36 of Set 7 | tazovskiy
# Processing Record 37 of Set 7 | lubao
# Processing Record 38 of Set 7 | zeya
# Processing Record 39 of Set 7 | quatre cocos
# Processing Record 40 of Set 7 | miles city
# Processing Record 41 of Set 7 | fortuna
# Processing Record 42 of Set 7 | hanyang
# Processing Record 43 of Set 7 | kirkwall
# Processing Record 44 of Set 7 | verkhnyaya toyma
# Processing Record 45 of Set 7 | dingle
# Processing Record 46 of Set 7 | praia da vitoria
# Processing Record 47 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 7 | liverpool
# Processing Record 49 of Set 7 | kopong
# Processing Record 0 of Set 8 | flinders
# Processing Record 1 of Set 8 | palmer
# Processing Record 2 of Set 8 | makakilo city
# Processing Record 3 of Set 8 | quelimane
# Processing Record 4 of Set 8 | aloleng
# Processing Record 5 of Set 8 | draguignan
# Processing Record 6 of Set 8 | barreirinhas
# Processing Record 7 of Set 8 | lompoc
# Processing Record 8 of Set 8 | yinchuan
# Processing Record 9 of Set 8 | klaksvik
# Processing Record 10 of Set 8 | mayumba
# Processing Record 11 of Set 8 | anklesvar
# City not found. Skipping...
# Processing Record 12 of Set 8 | sola
# Processing Record 13 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 8 | korla
# City not found. Skipping...
# Processing Record 15 of Set 8 | lhuntshi
# City not found. Skipping...
# Processing Record 16 of Set 8 | amga
# Processing Record 17 of Set 8 | anito
# Processing Record 18 of Set 8 | qui nhon
# City not found. Skipping...
# Processing Record 19 of Set 8 | birjand
# Processing Record 20 of Set 8 | evensk
# Processing Record 21 of Set 8 | natal
# Processing Record 22 of Set 8 | piacabucu
# Processing Record 23 of Set 8 | tarare
# Processing Record 24 of Set 8 | san andres
# Processing Record 25 of Set 8 | moose factory
# Processing Record 26 of Set 8 | itarantim
# Processing Record 27 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 8 | praya
# Processing Record 29 of Set 8 | atar
# Processing Record 30 of Set 8 | wilmington island
# Processing Record 31 of Set 8 | isangel
# Processing Record 32 of Set 8 | berlevag
# Processing Record 33 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 34 of Set 8 | gat
# Processing Record 35 of Set 8 | port-gentil
# Processing Record 36 of Set 8 | jawhar
# Processing Record 37 of Set 8 | wajima
# Processing Record 38 of Set 8 | henties bay
# Processing Record 39 of Set 8 | warrnambool
# Processing Record 40 of Set 8 | kayes
# Processing Record 41 of Set 8 | goderich
# Processing Record 42 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 43 of Set 8 | kahului
# Processing Record 44 of Set 8 | port lincoln
# Processing Record 45 of Set 8 | lovington
# Processing Record 46 of Set 8 | bilma
# Processing Record 47 of Set 8 | kirando
# Processing Record 48 of Set 8 | andenes
# City not found. Skipping...
# Processing Record 49 of Set 8 | el salto
# Processing Record 0 of Set 9 | narsaq
# Processing Record 1 of Set 9 | culebra
# Processing Record 2 of Set 9 | nunkini
# Processing Record 3 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 9 | pahrump
# Processing Record 5 of Set 9 | koumac
# Processing Record 6 of Set 9 | san policarpo
# Processing Record 7 of Set 9 | mpongwe
# Processing Record 8 of Set 9 | simplicio mendes
# Processing Record 9 of Set 9 | mercedes
# Processing Record 10 of Set 9 | goure
# Processing Record 11 of Set 9 | saldanha
# Processing Record 12 of Set 9 | college
# Processing Record 13 of Set 9 | luderitz
# Processing Record 14 of Set 9 | bud
# Processing Record 15 of Set 9 | paramonga
# Processing Record 16 of Set 9 | aleppo
# Processing Record 17 of Set 9 | adrar
# Processing Record 18 of Set 9 | nabire
# Processing Record 19 of Set 9 | meulaboh
# Processing Record 20 of Set 9 | kareli
# Processing Record 21 of Set 9 | ahipara
# Processing Record 22 of Set 9 | beringovskiy
# Processing Record 23 of Set 9 | praia
# Processing Record 24 of Set 9 | tawau
# Processing Record 25 of Set 9 | labuan
# Processing Record 26 of Set 9 | maputo
# Processing Record 27 of Set 9 | grand-lahou
# Processing Record 28 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 29 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 9 | belmonte
# Processing Record 31 of Set 9 | saskylakh
# Processing Record 32 of Set 9 | ilo
# Processing Record 33 of Set 9 | cidreira
# Processing Record 34 of Set 9 | kichera
# Processing Record 35 of Set 9 | lethem
# Processing Record 36 of Set 9 | severo-kurilsk
# Processing Record 37 of Set 9 | margate
# Processing Record 38 of Set 9 | vao
# Processing Record 39 of Set 9 | kanigiri
# Processing Record 40 of Set 9 | troitsko-pechorsk
# Processing Record 41 of Set 9 | tatawin
# City not found. Skipping...
# Processing Record 42 of Set 9 | stokmarknes
# Processing Record 43 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 9 | new glasgow
# Processing Record 45 of Set 9 | loukhi
# Processing Record 46 of Set 9 | lagunas
# Processing Record 47 of Set 9 | shu
# Processing Record 48 of Set 9 | tottori
# Processing Record 49 of Set 9 | bilibino
# Processing Record 0 of Set 10 | rafaela
# Processing Record 1 of Set 10 | sioux lookout
# Processing Record 2 of Set 10 | anadyr
# Processing Record 3 of Set 10 | tongren
# Processing Record 4 of Set 10 | takoradi
# Processing Record 5 of Set 10 | san patricio
# Processing Record 6 of Set 10 | karratha
# Processing Record 7 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 10 | sur
# Processing Record 9 of Set 10 | elko
# Processing Record 10 of Set 10 | phan thiet
# Processing Record 11 of Set 10 | dukat
# Processing Record 12 of Set 10 | iquitos
# Processing Record 13 of Set 10 | paita
# Processing Record 14 of Set 10 | port macquarie
# Processing Record 15 of Set 10 | villacarrillo
# Processing Record 16 of Set 10 | santa isabel do rio negro
# Processing Record 17 of Set 10 | perevolotskiy
# Processing Record 18 of Set 10 | inyonga
# Processing Record 19 of Set 10 | port shepstone
# Processing Record 20 of Set 10 | the pas
# Processing Record 21 of Set 10 | sulejowek
# Processing Record 22 of Set 10 | badiraguato
# Processing Record 23 of Set 10 | bagdarin
# Processing Record 24 of Set 10 | kodinsk
# Processing Record 25 of Set 10 | brae
# Processing Record 26 of Set 10 | sandnessjoen
# Processing Record 27 of Set 10 | la ronge
# Processing Record 28 of Set 10 | cobija
# Processing Record 29 of Set 10 | hereford
# Processing Record 30 of Set 10 | gao
# Processing Record 31 of Set 10 | preston
# Processing Record 32 of Set 10 | anori
# Processing Record 33 of Set 10 | olafsvik
# City not found. Skipping...
# Processing Record 34 of Set 10 | kyra
# City not found. Skipping...
# Processing Record 35 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 10 | maniitsoq
# Processing Record 37 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 38 of Set 10 | jalu
# Processing Record 39 of Set 10 | santa maria
# Processing Record 40 of Set 10 | nizhniy tsasuchey
# Processing Record 41 of Set 10 | pucara
# Processing Record 42 of Set 10 | valdivia
# Processing Record 43 of Set 10 | verkh-usugli
# Processing Record 44 of Set 10 | semirom
# Processing Record 45 of Set 10 | padang
# Processing Record 46 of Set 10 | weligama
# Processing Record 47 of Set 10 | hongjiang
# Processing Record 48 of Set 10 | presidencia roque saenz pena
# Processing Record 49 of Set 10 | dunedin
# Processing Record 0 of Set 11 | ilulissat
# Processing Record 1 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 11 | toulepleu
# City not found. Skipping...
# Processing Record 3 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 11 | camocim
# Processing Record 5 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 11 | amarkantak
# Processing Record 7 of Set 11 | harper
# Processing Record 8 of Set 11 | iacu
# Processing Record 9 of Set 11 | shambu
# Processing Record 10 of Set 11 | riyadh
# Processing Record 11 of Set 11 | morondava
# Processing Record 12 of Set 11 | buala
# Processing Record 13 of Set 11 | mackenzie
# Processing Record 14 of Set 11 | union
# Processing Record 15 of Set 11 | crepy-en-valois
# Processing Record 16 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 11 | kushmurun
# City not found. Skipping...
# Processing Record 18 of Set 11 | mahenge
# Processing Record 19 of Set 11 | diego de almagro
# Processing Record 20 of Set 11 | luanda
# Processing Record 21 of Set 11 | bobrovytsya
# Processing Record 22 of Set 11 | mahroni
# Processing Record 23 of Set 11 | eagle
# Processing Record 24 of Set 11 | vitorino freire
# Processing Record 25 of Set 11 | huancavelica
# Processing Record 26 of Set 11 | yilan
# Processing Record 27 of Set 11 | tenextatiloyan
# City not found. Skipping...
# Processing Record 28 of Set 11 | romny
# Processing Record 29 of Set 11 | boralday
# Processing Record 30 of Set 11 | muros
# Processing Record 31 of Set 11 | calderitas
# Processing Record 32 of Set 11 | maumere
# Processing Record 33 of Set 11 | boende
# Processing Record 34 of Set 11 | joshimath
# Processing Record 35 of Set 11 | moerai
# Processing Record 36 of Set 11 | lilongwe
# Processing Record 37 of Set 11 | esso
# Processing Record 38 of Set 11 | beloha
# Processing Record 39 of Set 11 | xining
# Processing Record 40 of Set 11 | neuquen
# Processing Record 41 of Set 11 | vondrozo
# Processing Record 42 of Set 11 | lorengau
# Processing Record 43 of Set 11 | petukhovo
# Processing Record 44 of Set 11 | yuancheng
# City not found. Skipping...
# Processing Record 45 of Set 11 | batsfjord
# Processing Record 46 of Set 11 | erenhot
# Processing Record 47 of Set 11 | tabou
# Processing Record 48 of Set 11 | mocuba
# Processing Record 49 of Set 11 | tukrah
# City not found. Skipping...
# Processing Record 0 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 12 | itaituba
# Processing Record 2 of Set 12 | sete
# Processing Record 3 of Set 12 | puyang
# Processing Record 4 of Set 12 | erzin
# Processing Record 5 of Set 12 | cerro largo
# Processing Record 6 of Set 12 | agvali
# Processing Record 7 of Set 12 | marawi
# Processing Record 8 of Set 12 | hami
# Processing Record 9 of Set 12 | maningrida
# Processing Record 10 of Set 12 | flin flon
# Processing Record 11 of Set 12 | grindavik
# Processing Record 12 of Set 12 | ust-kuyga
# Processing Record 13 of Set 12 | buchanan
# Processing Record 14 of Set 12 | moron
# Processing Record 15 of Set 12 | mwense
# Processing Record 16 of Set 12 | dalvik
# Processing Record 17 of Set 12 | muisne
# Processing Record 18 of Set 12 | mangai
# Processing Record 19 of Set 12 | kokopo
# Processing Record 20 of Set 12 | kalamakion
# City not found. Skipping...
# Processing Record 21 of Set 12 | yei
# City not found. Skipping...
# Processing Record 22 of Set 12 | mabaruma
# Processing Record 23 of Set 12 | ukiah
# Processing Record 24 of Set 12 | kars
# Processing Record 25 of Set 12 | ixtapa
# Processing Record 26 of Set 12 | ylivieska
# Processing Record 27 of Set 12 | okhotsk
# Processing Record 28 of Set 12 | miri
# Processing Record 29 of Set 12 | kungurtug
# Processing Record 30 of Set 12 | chokwe
# City not found. Skipping...
# Processing Record 31 of Set 12 | grand forks
# Processing Record 32 of Set 12 | matara
# Processing Record 33 of Set 12 | sulphur springs
# Processing Record 34 of Set 12 | winnemucca
# Processing Record 35 of Set 12 | benghazi
# Processing Record 36 of Set 12 | cayenne
# Processing Record 37 of Set 12 | half moon bay
# Processing Record 38 of Set 12 | dasoguz
# Processing Record 39 of Set 12 | tsalka
# Processing Record 40 of Set 12 | oxbow
# Processing Record 41 of Set 12 | maple creek
# Processing Record 42 of Set 12 | inirida
# Processing Record 43 of Set 12 | bisira
# Processing Record 44 of Set 12 | spring hill
# Processing Record 45 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 46 of Set 12 | gerash
# Processing Record 47 of Set 12 | oussouye
# Processing Record 48 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 49 of Set 12 | shubarkuduk
# Processing Record 0 of Set 13 | ust-karsk
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
citydata_pd = pd.DataFrame(city_data)

lats = citydata_pd["Lat"]
max_temps = citydata_pd["Max Temp"]
humidity = citydata_pd["Humidity"]
cloudiness = citydata_pd["Cloudiness"]
wind_speed = citydata_pd["Wind Speed"]

# Export the City_Data into a csv
#city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
citydata_pd.count()
# Out:
# City          533
# Cloudiness    533
# Country       533
# Date          533
# Humidity      533
# Lat           533
# Lng           533
# Max Temp      533
# Wind Speed    533
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
citydata_pd.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       tezu           0      IN  1543876682        59  27.93   96.16
# 1    rikitea          92      PF  1543876660        99 -23.12 -134.97
# 2    ushuaia          40      AR  1543874400        66 -54.81  -68.31
# 3  jamestown           0      AU  1543876683        49 -33.21  138.60
# 4    may pen          20      JM  1543874400        54  17.97  -77.26
#
#    Max Temp  Wind Speed
# 0     49.85        1.86
# 1     78.65       11.88
# 2     50.00        8.05
# 3     71.68        6.40
# 4     84.20       16.11

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build scatter plot for latitude vs temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="red", linewidths=1, marker="o", 
            alpha=0.4, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Max_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for each city types
plt.scatter(lats, 
            humidity,
            edgecolor="blue", linewidths=1, marker="o", 
            alpha=0.4, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for each city types
plt.scatter(lats, 
            cloudiness,
            edgecolor="red", linewidths=1, marker="o", 
            alpha=0.4, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Cloudiness.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for each city types
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.4, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Wind Speed.png")

# Show plot
plt.show()
